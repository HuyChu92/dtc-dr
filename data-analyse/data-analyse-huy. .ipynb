# %%
import pandas as pd

df = pd.read_csv(r"D:\dtc-dr\data-analyse\continuous_factory_process.csv", delimiter=",")
df_types = df.dtypes 
# df_types.to_excel('datatypes.xlsx')
df.columns.tolist()
# Out:
# ['time_stamp',
#  'AmbientConditions.AmbientHumidity.U.Actual',
#  'AmbientConditions.AmbientTemperature.U.Actual',
#  'Machine1.RawMaterial.Property1',
#  'Machine1.RawMaterial.Property2',
#  'Machine1.RawMaterial.Property3',
#  'Machine1.RawMaterial.Property4',
#  'Machine1.RawMaterialFeederParameter.U.Actual',
#  'Machine1.Zone1Temperature.C.Actual',
#  'Machine1.Zone2Temperature.C.Actual',
#  'Machine1.MotorAmperage.U.Actual',
#  'Machine1.MotorRPM.C.Actual',
#  'Machine1.MaterialPressure.U.Actual',
#  'Machine1.MaterialTemperature.U.Actual',
#  'Machine1.ExitZoneTemperature.C.Actual',
#  'Machine2.RawMaterial.Property1',
#  'Machine2.RawMaterial.Property2',
#  'Machine2.RawMaterial.Property3',
#  'Machine2.RawMaterial.Property4',
#  'Machine2.RawMaterialFeederParameter.U.Actual',
#  'Machine2.Zone1Temperature.C.Actual',
#  'Machine2.Zone2Temperature.C.Actual',
#  'Machine2.MotorAmperage.U.Actual',
#  'Machine2.MotorRPM.C.Actual',
#  'Machine2.MaterialPressure.U.Actual',
# ...

# %%
df.mean()
# Out:
# C:\Users\huy_c\AppData\Local\Temp\ipykernel_41288\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# AmbientConditions.AmbientHumidity.U.Actual        15.330759
# AmbientConditions.AmbientTemperature.U.Actual     23.843635
# Machine1.RawMaterial.Property1                    11.851256
# Machine1.RawMaterial.Property2                   205.676320
# Machine1.RawMaterial.Property3                   951.679815
#                                                     ...
# Stage2.Output.Measurement12.U.Setpoint             1.850000
# Stage2.Output.Measurement13.U.Actual               3.535251
# Stage2.Output.Measurement13.U.Setpoint             2.890000
# Stage2.Output.Measurement14.U.Actual               7.515574
# ...

# %%
df.max()
# Out:
# time_stamp                                       2019-03-06 14:47:20
# AmbientConditions.AmbientHumidity.U.Actual                     17.24
# AmbientConditions.AmbientTemperature.U.Actual                  24.43
# Machine1.RawMaterial.Property1                                  12.9
# Machine1.RawMaterial.Property2                                   236
#                                                         ...
# Stage2.Output.Measurement12.U.Setpoint                          1.85
# Stage2.Output.Measurement13.U.Actual                             8.0
# Stage2.Output.Measurement13.U.Setpoint                          2.89
# Stage2.Output.Measurement14.U.Actual                           14.26
# Stage2.Output.Measurement14.U.Setpoint                         11.71
# Length: 116, dtype: object

# %%
df.min()
# Out:
# time_stamp                                       2019-03-06 10:52:33
# AmbientConditions.AmbientHumidity.U.Actual                     13.84
# AmbientConditions.AmbientTemperature.U.Actual                  23.02
# Machine1.RawMaterial.Property1                                 11.54
# Machine1.RawMaterial.Property2                                   200
#                                                         ...
# Stage2.Output.Measurement12.U.Setpoint                          1.85
# Stage2.Output.Measurement13.U.Actual                            -0.0
# Stage2.Output.Measurement13.U.Setpoint                          2.89
# Stage2.Output.Measurement14.U.Actual                       -3.437021
# Stage2.Output.Measurement14.U.Setpoint                         11.71
# Length: 116, dtype: object

# %%
df.median()
# Out:
# C:\Users\huy_c\AppData\Local\Temp\ipykernel_41288\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# AmbientConditions.AmbientHumidity.U.Actual        15.12
# AmbientConditions.AmbientTemperature.U.Actual     23.93
# Machine1.RawMaterial.Property1                    11.54
# Machine1.RawMaterial.Property2                   200.00
# Machine1.RawMaterial.Property3                   963.00
#                                                   ...
# Stage2.Output.Measurement12.U.Setpoint             1.85
# Stage2.Output.Measurement13.U.Actual               3.51
# Stage2.Output.Measurement13.U.Setpoint             2.89
# Stage2.Output.Measurement14.U.Actual               7.87
# Stage2.Output.Measurement14.U.Setpoint            11.71
# ...

# %%
df.mode()
# Out:
#             time_stamp  AmbientConditions.AmbientHumidity.U.Actual  \
# 0  2019-03-06 10:53:06                                       14.04
# 1                  NaN                                         NaN
# 2                  NaN                                         NaN
# 3                  NaN                                         NaN
#
#    AmbientConditions.AmbientTemperature.U.Actual  \
# 0                                          23.53
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
#
#    Machine1.RawMaterial.Property1  Machine1.RawMaterial.Property2  \
# 0                           11.54                           200.0
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\dtc-dr\data-analyse\data-analyse-huy. .ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/dtc-dr/data-analyse/data-analyse-huy.%20.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df.columns.tolist()
#
# NameError: name 'df' is not defined
